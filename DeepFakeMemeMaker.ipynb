# %% [markdown]
# <a href="https://colab.research.google.com/github/Reksy747/DeepFakeMemeMaker/blob/master/DeepFakeMemeMaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DeepFakeMemeMaker
# ### Demo for paper "First Order Motion Model for Image Animation"
# ### ORIGINAL CODE:
# ### https://github.com/AliaksandrSiarohin/first-order-model
# ### https://colab.research.google.com/github/AliaksandrSiarohin/first-order-model/blob/master/demo.ipynb

# %% [markdown]
# **BUAT FOLDER 'first-order-motion-model' di google drive mu
# dan upload video dan gambar yang akan di buat deepfake ke folder 'first-order-motion-model' yang telah di buat tadi**

# %% [markdown]
# **Video source untuk deepfake DAME MITAI :** https://drive.google.com/file/d/1HRwhF4A3UpvTJYJoYzfMw949i4chx_Qt/view
#
# **Video source untuk deepfake tokyo ghoul :** https://drive.google.com/file/d/1ypza5_fbi9urYCaAjczdqbRXLbtcnBKb/view?usp=sharing

# %% [markdown]
# **Tentukan nama file gambar dan driving video (sesuaikan dengan video yang anda upload ke gdrive di folder 'first-order-motion-model')**
#
# **Pastikan foto dan video yang ada upload ke folder 'first-order-motion-model' ukuranya 256x256 pixel**

# %%
DRIVING_VIDEO = "dameyo.mp4"
GAMBAR_TARGET = "bob.png"
OUTPUT = "DAME_MITAI_MEME.mp4"

# %% [markdown]
# **Clone repository**

# %%
# !git clone https://github.com/AliaksandrSiarohin/first-order-model
# Out:
# Cloning into 'first-order-model'...
# remote: Enumerating objects: 236, done.
# remote: Total 236 (delta 0), reused 0 (delta 0), pack-reused 236
# Receiving objects: 100% (236/236), 71.46 MiB | 8.73 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
cd /content/first-order-model
# Out:
# /content/first-order-model

# %% [markdown]
# **Mount your Google drive folder on Colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **COPY DATA vox-adv-cpk.pth.tar dan vox-cpk.pth.tar ke folder 'first-order-motion-model' yang telah di buat tadi
# filenya ada disini :** https://drive.google.com/drive/folders/1kZ1gCnpfU0BnpdU47pLM_TQ6RypDDqgw

# %% [markdown]
# **Load driving video and source image**

# %%
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from skimage.transform import resize
from IPython.display import HTML
import warnings
warnings.filterwarnings("ignore")

source_image = imageio.imread('/content/gdrive/My Drive/first-order-motion-model/{}'.format(GAMBAR_TARGET))
driving_video = imageio.mimread('/content/gdrive/My Drive/first-order-motion-model/{}'.format(DRIVING_VIDEO), memtest=False)


#Resize image and video to 256x256

source_image = resize(source_image, (256, 256))[..., :3]
driving_video = [resize(frame, (256, 256))[..., :3] for frame in driving_video]

def display(source, driving, generated=None):
    fig = plt.figure(figsize=(8 + 4 * (generated is not None), 6))

    ims = []
    for i in range(len(driving)):
        cols = [source]
        cols.append(driving[i])
        if generated is not None:
            cols.append(generated[i])
        im = plt.imshow(np.concatenate(cols, axis=1), animated=True)
        plt.axis('off')
        ims.append([im])

    ani = animation.ArtistAnimation(fig, ims, interval=50, repeat_delay=1000)
    plt.close()
    return ani
    

HTML(display(source_image, driving_video).to_html5_video())
# Out:
# <video width="576" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# **Create a model and load checkpoints**

# %%
from demo import load_checkpoints
generator, kp_detector = load_checkpoints(config_path='config/vox-256.yaml', 
                            checkpoint_path='/content/gdrive/My Drive/first-order-motion-model/vox-cpk.pth.tar')

# %% [markdown]
# **Perform image animation**

# %%
from demo import make_animation
from skimage import img_as_ubyte

predictions = make_animation(source_image, driving_video, generator, kp_detector, relative=True)

#save resulting video
imageio.mimsave('/content/gdrive/My Drive/first-order-motion-model/{}'.format(OUTPUT), [img_as_ubyte(frame) for frame in predictions])
#video can be downloaded from drive folder

HTML(display(source_image, driving_video, predictions).to_html5_video())
# Out:
# 100%|██████████| 672/672 [00:25<00:00, 26.10it/s]
# <video width="864" height="432" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# **JIKA SUDAH SELESAI SEMUA FILE HASIL RENDER ITU ADA DI GDRIVE KALIAN DI FOLDER 'first-order-motion-model' dan jangan lupa di edit di video editor yang kalian pakai dan set fps video ke 24fps**
